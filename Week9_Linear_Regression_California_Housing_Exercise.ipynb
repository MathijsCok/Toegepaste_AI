# %% [markdown]
# # Linear Regression on the California Housing Dataset
# This notebook walks you step-by-step through training a **Linear Regression model** using the **California Housing dataset**. We'll use the preprocessed data from last week and use it to train and evaluate a model. We'll cover best practices for data splitting in the next notebook.

# %% [markdown]
# ## 1. Import Required Libraries
#
# We begin by importing the Python libraries we'll need for data handling, visualization, and modelling.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## 2. Read and Preprocess California Housing Dataset
#
# We'll read the dataset and convert it to a DataFrame (df) and remove non-numerical columns or columns that contain missing values. We identified those columns in the last exercise. We then define our target variable y and training data X.

# %%
# Load the California housing dataset and show basic information
# get file path
import os

FileName = "housing.csv"
	
base_dir = os.getcwd()
path = os.path.join(base_dir, FileName)

print(path)

#read data
Data = pd.read_csv(path)

# investigate the data
print(Data)

# %% [markdown]
# ## 3: Scale the Training Data

# %% [markdown]
# ## 4: Train a Linear Regression Model
#
# We'll now train the Linear Regression model using our scaled training data.

# %% [markdown]
# Try to explain in your own words what happens when you call the model.fit function.

# %% [markdown]
# ## 5: Make Predictions
#
# Now that the model is trained, let's predict the housing values using our scaled training data.
#
# **Hint:**  `model.predict()` might be useful here

# %%
y_prod = Linear_model.predict(x_scaled)

# %% [markdown]
# ## 6: Evaluate Model Performance
#
# We'll use **Root Mean Squared Error (MSE)** to measure how well the model performs.

# %% [markdown]
# What does the root mean squared error (MSE) mean? How is it calculated? Is the RMSE you got good?

# %% [markdown]
# ## 7. Visualize Predictions
#
# Compare the **actual** vs **predicted** house values using a plot of your choice.

# %% [markdown]
# Do you notice something unusual?

# %% [markdown]
# ## 8. Inspect Model Coefficients
#
# Let's see which features have the most influence on the predicted house prices. Create a bar plot that shows the coefficients per column (feature). Estimated coefficients for a linear regression problem are stored in sklearn in an array called coef_.

# %%
# Extract coefficients


# Plot

# %% [markdown]
# Interpret what you see.
