# %% [markdown]
# ## Exercise: Calculate Statistics on California Housing Data
#
# In this exercise, you will load a real-world dataset and analyze a column of this data set containing house values in California. The dataset contains demographic and housing information for neighborhoods in California. It includes columns such as median income, house age, average number of rooms, population, and latitude/longitude. The numbers are aggregated by census block groups, not a single home.
#
# Follow the steps below.

# %% [markdown]
# ### 1. Import Libraries
# Below are the libraries numpy (for fast mathematical operations) and matplotlib (for creating visualizations) loaded. Add the pandas library.

# %%
import numpy as np
import matplotlib.pyplot as plt
# load pandas library here

# %% [markdown]
# ### 2. Load the Dataset
# Read the file housing.csv file as a pandas dataframe (df) and inspect the data. To read in the data you can use read_csv from pandas and to inspect the data the pandas function 'head' might be useful.

# %%
# read csv file


# inspect data

# %% [markdown]
# How many rows and columns are included? You can use the method 'shape' for this.

# %% [markdown]
# ### 3. Select a Column to Analyze
#
# We will focus on the house value (house_value), select it from the dataframe and store it in a variable.

# %% [markdown]
# ### 4. Compute Mean, Median, and Standard Deviation
# Now compute the mean, median and std of the house values. Those functions are already implemented in numpy. You can look up how to use them.

# %% [markdown]
# What is the difference between the mean and the median?
#
# How do outliers influence the results?

# %% [markdown]
# ### 5. Create a Histogram of the Data.
# Lastly, we want to create a histogram of the house values using the hist function in Matplotlib. Make sure the x- and y-axes are labeled correctly, and add a title to the plot. Investigate the plot, do you notice anything interesting?
