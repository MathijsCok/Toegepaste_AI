# %% [markdown]
# # Polynomial Regression on California Housing Dataset
# This notebook covers data loading, preprocessing, baseline linear regression, polynomial feature expansion, and model comparison.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Dataset
# Like last week, we read the data, remove non-numerical columns and define the target variable and the training data. Fill in the gaps (...) to complete the code.

# %%
df = pd.read_csv(...)
df = df.drop(['ocean_proximity','total_bedrooms'], axis=1)
X = df.drop('house_value', axis=1)
y = df[...]

# %% [markdown]
# ## 2. Train/Validation/Test Split
# As we have seen in the lecture, we need to split the data into training, validation, and testing set according to best practices. Make a choice on the size of the resulting sets.
#
# **Hint:** you can use the sklearn function `train_test_split()` twice for this.

# %% [markdown]
# Investigate the shape of the resulting datasets. Explain what you see.

# %% [markdown]
# ## 3. Scaling
# Fit the scaler using the training data and transform training, validation and test data (seperately).

# %% [markdown]
# ## 4. Baseline Linear Regression
# Now we create a train a baseline linear regression model on the training data.

# %% [markdown]
# Make predictions on the validation data.

# %% [markdown]
# Calculate the root mean squared error on the validation data.

# %% [markdown]
# ## 4. Polynomial Features (degree = 2)
# Now its time to fit a polynomial, we can easily do this by transforming the data. For this, we can generate a new feature matrix consisting of all polynomial combinations of the features (columns). For example, if the input is two dimensional and of the form [a, b], the degree-2 polynomial features are [$1, a, b, a^2, ab, b^2$]. After this we can fit a linear regression model on the transformed data, thereby effectively fitting a polynomial model.
#
# **Hint:** you can look up `PolynomialFeatures` for this.

# %% [markdown]
# Compare the shape of X_train and X_train_poly and expalin what you see. Does that match your expectation?

# %% [markdown]
# ## 5. Polynomial Regression Model
# Now we want to fit the model. As mentioned before, we we can fit a linear regression model on the transformed data, thereby effectively fitting a polynomial model.

# %% [markdown]
# Make predicions on the transformed validation data using the polynomial model. Calcuate the RMSE.

# %% [markdown]
# Compare the two models, which one is better?

# %% [markdown]
# ## 6. Optional: Different Degrees
# Systematically compare the RMSE on both the training and validation datasets using different polynomial degrees (e.g., from 1 to 5), and store the results in arrays. A pipeline might be helpful here to streamline the workflow and avoid repetitive code. If you would like to learn more about pipelines, you can read this blog post:
# [Scikit-learn Pipelines Explained](https://medium.com/@sahin.samia/scikit-learn-pipelines-explained-streamline-and-optimize-your-machine-learning-processes-f17b1beb86a4)

# %% [markdown]
# Plot both the training and validation errors vs the polynomial degree in one plot.

# %% [markdown]
# ## 7. Final evaluation on the test set.
# Choose the best-performing model and perform a final evaluation on the test set by calculating the RMSE on that data.
