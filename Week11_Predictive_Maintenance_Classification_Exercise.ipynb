# %% [markdown]
# # Exercise: Predictive Maintenance Classification
# This notebook covers predictive maintenance classification tasks, including data loading, preprocessing, model training, and evaluation. We want to predict, if a machine fails or not based on the sensor data we used previously. Follow instructions in each section to complete the exercise.

# %%
# Import libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# # Data Loading
# We load the predicitve maintenance data set (Predictive_Maintenance.csv) from the visualisation exercise.

# %%
# Load Data

# %% [markdown]
# Confirm correct data loading and perform a brief data check including checking the data types of each column.

# %% [markdown]
# ## Preprocessing
# As in previous exercises, we need to preprocess the data.
# First, create the target variable y containing the value we want to predict (Machine failure). Then, create the training data X by removing the target and additionally removing values of the type object.

# %%
# Target: 'machine_failure'

# %% [markdown]
# ## Data Splits
# Create training, validation, and test data sets. Make choices on the size of the data sets.

# %% [markdown]
# ## Scaling
# Scale your data. As usual, only fit the scaler on the training data and transform all three data sets.

# %% [markdown]
# ## K-nearest Neighbors (KNN)
# Create a KNeighborsClassifier using the 3 nearest neighbors and fit it to the scaled training data.

# %% [markdown]
# Use the KNN model to make predictions on the scaled validation data.

# %%
# KNN

# %% [markdown]
# Calculate the accuracy score by comparing the predictions with the known target values.

# %% [markdown]
# ## Decision Tree
# Now repeat the process with a DecisionTreeClassifier: train a decision tree using the default hyperparameters, make predictions on the validation data, and calculate the accuracy.

# %%
# Decision Tree

# %%
# make predictions and calculate accuracy

# %% [markdown]
# ## Random Forest
# Lastly, train and evaluate a RandomForestClassifier the same way.

# %%
# Random Forest

# %%
# make predictions on validation data and calculate accuracy

# %% [markdown]
# ## Final Model
# Which model performs best? Use the best model to make predictions on the test data and calculate the accuracy on the test data.
